# %%
# %pip install pdfminer.six pandas
# Out:
# Requirement already satisfied: pdfminer.six in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (20250506)
# Requirement already satisfied: pandas in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six) (45.0.4)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: cffi>=1.14 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six) (2.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Part 1: Import Libraries and Initialize Directories
import os
import re
import csv
import logging
from datetime import datetime
import pandas as pd

# Define base directory (aligned with 01_scraper.py)
try:
    BASE_DIR = os.path.dirname(os.getcwd())  # Parent of 'notebooks'
except NameError:
    BASE_DIR = os.getcwd()  # Fallback for interactive environments like Jupyter

# Define paths
PATH_OUTPUT = os.path.join(BASE_DIR, 'data', 'raw')  # Where text files are read from
PATH_CSV = os.path.join(BASE_DIR, 'data', 'processed', 'cases.csv')  # Where CSV output is saved
LOG_DIR = os.path.join(BASE_DIR, 'logs')
LOG_PATH = os.path.join(LOG_DIR, 'metadata_extraction.log')

# Validate path length for Windows
MAX_PATH_LENGTH = 260

def validate_path(path):
    if len(path) > MAX_PATH_LENGTH:
        raise ValueError(f"Path {path} exceeds Windows maximum length of {MAX_PATH_LENGTH} characters")
    return path

# Ensure directories exist
for path in [LOG_DIR, os.path.dirname(PATH_CSV), PATH_OUTPUT]:
    try:
        validate_path(path)
        os.makedirs(path, exist_ok=True)
        logging.info(f"Directory ensured: {path}")
    except ValueError as e:
        logging.error(f"Path validation failed: {e}")
        raise
    except Exception as e:
        logging.error(f"Failed to create directory {path}: {e}")
        raise

# Initialize logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(LOG_PATH, mode='w', encoding='utf-8'),  # Overwrite mode
        logging.StreamHandler()
    ],
    force=True
)
logging.info("Starting metadata extraction process at %s", datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

# Part 2: Utility Functions
def clean_name(name):
    """Clean the extracted name by removing titles and extra spaces."""
    titles = [r'dr\.', r'drh\.', r'sh\.', r'mh\.', r'm\.h\.', r's\.h\.', r'prof\.', r'ir\.', r'hj\.', r'h\.']
    for title in titles:
        name = re.sub(title, '', name, flags=re.IGNORECASE)
    return ' '.join(name.split()).strip()

# Map Indonesian month names to English
month_map = {
    'januari': 'January',
    'februari': 'February',
    'maret': 'March',
    'april': 'April',
    'mei': 'May',
    'juni': 'June',
    'juli': 'July',
    'agustus': 'August',
    'september': 'September',
    'oktober': 'October',
    'november': 'November',
    'desember': 'December'
}

# Part 3: Metadata Extraction Function
def extract_metadata(text, file_name):
    metadata = {
        'case_id': file_name.replace('.txt', ''),
        'nomor_perkara': '',
        'tahun_putusan': '',
        'bulan_putusan': '',
        'tanggal_putusan': '',
        'jenis_perkara': '',
        'tingkat_pemeriksaan': '',
        'lembaga_peradilan': '',
        'pasal': '',
        'hakim_ketua': '',
        'ringkasan_fakta': '',
        'jumlah_kata_putusan': 0,
        'full_text': text
    }

    # Log a sample of the text to verify content
    logging.debug(f"Sample text for {file_name}: {text[:200]}")

    # Extract nomor_perkara with multiple patterns
    patterns = [
        r'(?:penetapan|putusan)\s+nomor\s*(\d+\s*pdt\s*p\s*\d{4})(?:\s*pn\s*\w+)?',
        r'(?:penetapan|putusan)\s+nomor\s*(\d+\s*pdt\s*g\s*\d{4})(?:\s*pa\s*\w+)?',
        r'(?:penetapan|putusan)\s+nomor\s*(\d+\s*pdt\s*\d{4})(?:\s*pt\s*\w+)?',
        r'(?:penetapan|putusan)\s+nomor\s*(\d+\s*(?:pk|k)\s*pid\s*sus\s*\d{4})',
        r'nomor\s*(\d+\s*(?:pk|k|pdt\s*p|pdt\s*g|pdt)\s*(?:pid\s*sus\s*)?\d{4})'
    ]
    for pattern in patterns:
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            metadata['nomor_perkara'] = match.group(1).replace('\s+', ' ').strip()
            logging.info(f"Extracted nomor_perkara from pattern: {metadata['nomor_perkara']} for {file_name}")
            break
    else:
        logging.warning(f"No nomor_perkara found in {file_name}. Sample text: {text[:200]}")

    # Extract case year from nomor_perkara for validation and tahun_putusan
    case_year = None
    case_year_match = re.search(r'(\d{4})$', metadata['nomor_perkara'])
    if case_year_match:
        case_year = int(case_year_match.group(1))
        metadata['tahun_putusan'] = str(case_year)
        logging.info(f"Extracted case year from nomor_perkara: {case_year} for {file_name}")

    # Extract tanggal/bulan/tahun putusan
    date_patterns = [
        r'(?:putusan|ditetapkan)\s+.*?tanggal\s+(\d{1,2}\s+\w+\s+\d{4})',
        r'tanggal\s+putusan\s+(\d{1,2}\s+\w+\s+\d{4})',
        r'tanggal\s+(\d{1,2}\s+\w+\s+\d{4})(?=\s*(?:diucapkan|ditetapkan|sidang))',
        r'(\d{1,2}\s+\w+\s+\d{4})(?=\s*(?:diucapkan|ditetapkan|sidang))',
        r'(\d{1,2}\s+\w+\s+\d{4})'
    ]
    date_formats = ['%d %B %Y', '%d %b %Y', '%d %m %Y']

    date_found = False
    for pattern in date_patterns:
        matches = re.finditer(pattern, text, re.IGNORECASE)
        for match in matches:
            full_date = match.group(1)
            for id_month, en_month in month_map.items():
                full_date = re.sub(rf'\b{id_month}\b', en_month, full_date, flags=re.IGNORECASE)
            for fmt in date_formats:
                try:
                    date_obj = datetime.strptime(full_date, fmt)
                    extracted_year = date_obj.year
                    if case_year and abs(extracted_year - case_year) > 5:
                        logging.warning(f"Extracted year {extracted_year} differs significantly from case year {case_year} in {file_name}. Using case year.")
                        continue
                    if extracted_year < 2000:
                        logging.warning(f"Extracted year {extracted_year} seems too early for {file_name}. Skipping.")
                        continue
                    metadata['tahun_putusan'] = str(case_year) if case_year else str(extracted_year)
                    metadata['bulan_putusan'] = date_obj.strftime('%B')
                    metadata['tanggal_putusan'] = str(date_obj.day)
                    date_found = True
                    logging.info(f"Extracted date: {full_date} (Year: {metadata['tahun_putusan']}, Month: {metadata['bulan_putusan']}, Day: {metadata['tanggal_putusan']}) for {file_name}")
                    break
                except ValueError:
                    continue
            if date_found:
                break
        if date_found:
            break
    if not date_found and case_year:
        logging.warning(f"No valid decision date found in {file_name}. Using case year {case_year} as tahun_putusan.")
        metadata['tahun_putusan'] = str(case_year)
    elif not date_found:
        logging.warning(f"No valid decision date or case year found in {file_name}.")

    # Jenis perkara
    if 'korupsi' in text.lower() or 'tindak pidana korupsi' in text.lower():
        metadata['jenis_perkara'] = 'Pidana Khusus Korupsi'
        logging.info(f"Set jenis_perkara to 'Pidana Khusus Korupsi' for {file_name}")
    elif 'pdt' in text.lower():
        metadata['jenis_perkara'] = 'Perdata'
        logging.info(f"Set jenis_perkara to 'Perdata' for {file_name}")
    else:
        logging.warning(f"No jenis_perkara identified in {file_name}.")

    # Tingkat pemeriksaan
    if 'peninjauan kembali' in text.lower():
        metadata['tingkat_pemeriksaan'] = 'Peninjauan Kembali'
    elif 'kasasi' in text.lower():
        metadata['tingkat_pemeriksaan'] = 'Kasasi'
    elif 'banding' in text.lower():
        metadata['tingkat_pemeriksaan'] = 'Banding'
    else:
        metadata['tingkat_pemeriksaan'] = 'Pertama'
    logging.info(f"Set tingkat_pemeriksaan to '{metadata['tingkat_pemeriksaan']}' for {file_name}")

    # Lembaga peradilan
    if 'mahkamah agung' in text.lower():
        metadata['lembaga_peradilan'] = 'Mahkamah Agung'
    elif 'pengadilan tinggi' in text.lower():
        metadata['lembaga_peradilan'] = 'Pengadilan Tinggi'
    elif 'pengadilan agama' in text.lower():
        metadata['lembaga_peradilan'] = 'Pengadilan Agama'
    elif 'pengadilan negeri' in text.lower():
        metadata['lembaga_peradilan'] = 'Pengadilan Negeri'
    else:
        metadata['lembaga_peradilan'] = 'Unknown'
    logging.info(f"Set lembaga_peradilan to '{metadata['lembaga_peradilan']}' for {file_name}")

    # Pasal
    match = re.search(r'(pasal\s+\d+(?:\s+ayat\s+\d+)?)\s+juncto\s+pasal\s+\d+\s+undang\s+undang\s+nomor\s+(\d+\s+tahun\s+\d{4})', text, re.IGNORECASE)
    if match:
        article = match.group(1).replace('\s+', ' ').strip()
        law = match.group(2).replace('\s+', ' ').strip()
        metadata['pasal'] = f"{article}, Undang-Undang Nomor {law}"
        logging.info(f"Extracted pasal: {metadata['pasal']} for {file_name}")
    else:
        match = re.search(r'(pasal\s+\d+(?:\s+ayat\s+\d+)?)', text, re.IGNORECASE)
        if match:
            metadata['pasal'] = match.group(1).replace('\s+', ' ').strip()
            logging.info(f"Extracted fallback pasal: {metadata['pasal']} for {file_name}")
        else:
            logging.warning(f"No pasal found in { file_name}.")

    # Hakim ketua
    match = re.search(r'ketua\s+majelis\s+([^\s][^,]+?)(?=\s+dan\s+[^\s].*?\s+hakim\s+hakim\s+anggota)', text, re.IGNORECASE)
    if match:
        metadata['hakim_ketua'] = clean_name(match.group(1))
        logging.info(f"Extracted hakim_ketua: {metadata['hakim_ketua']} for {file_name}")
    else:
        logging.warning(f"No hakim_ketua found in {file_name}")

    # Ringkasan fakta
    fact_patterns = [
        r'm\s*e\s*n\s*g\s*a\s*d\s*i\s*l\s*i\s+([^\s].*?)(?=\s*m\s*e\s*n\s*i\s*m\s*b\s*a\s*n\s*g|\s*d\s*e\s*m\s*i\s*k\s*i\s*a\s*n|\s*$)',
        r'(?:terdakwa|terpidana)\s+[^\s]+.*?didakwa\s+dengan\s+dakwaan\s+sebagai\s+berikut\s+([^\s].*?)(?=\s*m\s*e\s*n\s*i\s*m\s*b\s*a\s*n\s*g|\s*d\s*e\s*m\s*i\s*k\s*i\s*a\s*n|\s*$)',
        r'm\s*e\s*m\s*e\s*r\s*i\s*k\s*s\s*a\s+\s*p\s*e\s*r\s*k\s*a\s*r\s*a\s+([^\s].*?)(?=\s*m\s*e\s*n\s*i\s*m\s*b\s*a\s*n\s*g|\s*d\s*e\s*m\s*i\s*k\s*i\s*a\s*n|\s*$)',
        r'karena\s+didakwa\s+dengan\s+dakwaan\s+sebagai\s+berikut\s+([^\s].*?)(?=\s*m\s*e\s*n\s*i\s*m\s*b\s*a\s*n\s*g|\s*d\s*e\s*m\s*i\s*k\s*i\s*a\s*n|\s*$)'
    ]
    for idx, pattern in enumerate(fact_patterns, 1):
        match = re.search(pattern, text, re.IGNORECASE | re.DOTALL)
        if match:
            fact_text = ' '.join(match.group(1).split())
            if len(fact_text) > 50:
                metadata['ringkasan_fakta'] = fact_text[:1000] + '...' if len(fact_text) > 1000 else fact_text
                logging.info(f"Extracted ringkasan_fakta using pattern {idx} for {file_name}: {metadata['ringkasan_fakta'][:200]}")
                break
    else:
        logging.warning(f"No ringkasan_fakta found in {file_name}.")

    metadata['jumlah_kata_putusan'] = len(text.split())
    logging.info(f"Extracted jumlah_kata_putusan: {metadata['jumlah_kata_putusan']} for {file_name}")

    return metadata

# Part 4: CSV Saving Function
def save_to_csv(metadata_list):
    fieldnames = [
        'case_id', 'nomor_perkara', 'tahun_putusan', 'bulan_putusan', 'tanggal_putusan',
        'jenis_perkara', 'tingkat_pemeriksaan', 'lembaga_peradilan',
        'pasal', 'hakim_ketua', 'ringkasan_fakta', 'jumlah_kata_putusan', 'full_text'
    ]
    try:
        os.makedirs(os.path.dirname(PATH_CSV), exist_ok=True)
        with open(PATH_CSV, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            for metadata in metadata_list:
                writer.writerow(metadata)
                logging.info(f"Wrote metadata for case_id: {metadata['case_id']}")
        logging.info(f"Saved {len(metadata_list)} metadata entries to {PATH_CSV}")
    except Exception as e:
        logging.error(f"Failed to save CSV to {PATH_CSV}: {e}")
        raise

# Part 5: Main Processing Function
def process_text_files():
    metadata_list = []
    if not os.path.exists(PATH_OUTPUT):
        logging.error(f"Directory {PATH_OUTPUT} does not exist. Please ensure 01_scraper.py has run successfully.")
        print(f"Error: Directory {PATH_OUTPUT} does not exist.")
        return

    text_files = [f for f in os.listdir(PATH_OUTPUT) if f.endswith('.txt')]
    if not text_files:
        logging.warning(f"No .txt files found in {PATH_OUTPUT}. Please check if 01_scraper.py generated text files.")
        print(f"No .txt files found in {PATH_OUTPUT}.")
        return
    logging.info(f"Found {len(text_files)} text files to process in {PATH_OUTPUT}")

    for text_file in text_files:
        file_path = os.path.join(PATH_OUTPUT, text_file)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                text = f.read().strip()
            if not text:
                logging.warning(f"Text file {text_file} is empty")
                continue
            metadata = extract_metadata(text, text_file)
            metadata_list.append(metadata)
            logging.info(f"Processed text file: {text_file}")
        except UnicodeDecodeError:
            logging.warning(f"Encoding error in {text_file}. Trying 'latin-1' encoding.")
            try:
                with open(file_path, 'r', encoding='latin-1') as f:
                    text = f.read().strip()
                if not text:
                    logging.warning(f"Text file {text_file} is empty after retry")
                    continue
                metadata = extract_metadata(text, text_file)
                metadata_list.append(metadata)
                logging.info(f"Processed text file with latin-1 encoding: {text_file}")
            except Exception as e:
                logging.error(f"Failed to process {text_file} with latin-1 encoding: {e}")
                continue
        except Exception as e:
            logging.error(f"Error processing {text_file}: {e}")
            continue

    if metadata_list:
        save_to_csv(metadata_list)
        print(f"Processed {len(metadata_list)} files and saved to {PATH_CSV}")
    else:
        logging.warning("No files processed or no metadata extracted")
        print("No files processed or no metadata extracted")

# Part 6: Main Execution
if __name__ == "__main__":
    process_text_files()
# Out:
# 2025-06-25 10:35:34,075 - INFO - Directory ensured: d:\AL FITRA\STUDI UMM\SEMESTER 6\TEORI\PENALARAN KOMPUTER\SOURCE CODE\PENALARAN KOMPUTER\CBR_Penalararan_Komputer\CBR\logs
# 2025-06-25 10:35:34,076 - INFO - Directory ensured: d:\AL FITRA\STUDI UMM\SEMESTER 6\TEORI\PENALARAN KOMPUTER\SOURCE CODE\PENALARAN KOMPUTER\CBR_Penalararan_Komputer\CBR\data\processed
# 2025-06-25 10:35:34,078 - INFO - Directory ensured: d:\AL FITRA\STUDI UMM\SEMESTER 6\TEORI\PENALARAN KOMPUTER\SOURCE CODE\PENALARAN KOMPUTER\CBR_Penalararan_Komputer\CBR\data\raw
- INFO - Set tingkat_pemeriksaan to 'Pertama' for case_014.txt
# 2025-06-25 10:35:34,358 - INFO - Set lembaga_peradilan to 'Pengadilan Negeri' for case_014.txt
# 2025-06-25 10:35:34,359 - INFO - Extracted fallback pasal: pasal 271 for case_014.txt
# 2025-06-25 10:35:34,360 - WARNING - No hakim_ketua found in case_014.txt
# 2025-06-25 10:35:34,360 - INFO - Extracted ringkasan_fakta using pattern 1 for case_014.txt: perkaraperdata permohonan telah memberikan penetapan sebagai berikut dalampermohonan yang diajukan oleh rimson sinaga pekerjaan swasta alamat upahoda desa hutatinggikecamatan pangururan kabupaten samo
# 2025-06-25 10:35:34,361 - INFO - Extracted jumlah_kata_putusan: 741 for case_014.txt
# 2025-06-25 10:35:34,362 - INFO - Completed metadata extraction for case_014.txt
# 2025-06-25 10:35:34,362 - INFO - Processed text file: case_014.txt
# 2025-06-25 10:35:34,364 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pdt' pattern: 429 pdt 2025 for case_015.txt
# 2025-06-25 10:35:34,365 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2025 for case_015.txt
# 2025-06-25 10:35:34,366 - INFO - Extracted date: 5 August 2024 (Year: 2025, Month: August, Day: 5) for case_015.txt
# 2025-06-25 10:35:34,367 - INFO - Set jenis_perkara to 'Perdata' for case_015.txt
# 2025-06-25 10:35:34,367 - INFO - Set tingkat_pemeriksaan to 'Banding' for case_015.txt
# 2025-06-25 10:35:34,368 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_015.txt
# 2025-06-25 10:35:34,369 - INFO - Extracted fallback pasal: pasal 6 for case_015.txt
# 2025-06-25 10:35:34,371 - WARNING - No hakim_ketua found in case_015.txt
# 2025-06-25 10:35:34,372 - INFO - Extracted ringkasan_fakta using pattern 1 for case_015.txt: perkara perdata padatingkat banding telah menjatuhkan putusan seperti tersebut di bawah ini dalamperkara antara 1 muhaji laki laki alamat di dusun gading watu rt 02 rw 05 desa gadingwatu kecamatan men
# 2025-06-25 10:35:34,373 - INFO - Extracted jumlah_kata_putusan: 1577 for case_015.txt
# 2025-06-25 10:35:34,374 - INFO - Completed metadata extraction for case_015.txt
# 2025-06-25 10:35:34,374 - INFO - Processed text file: case_015.txt
# 2025-06-25 10:35:34,376 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pid sus' pattern: 4824k pid sus 2024 for case_016.txt
# 2025-06-25 10:35:34,376 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2024 for case_016.txt
# 2025-06-25 10:35:34,377 - INFO - Extracted date: 13 October 2023 (Year: 2024, Month: October, Day: 13) for case_016.txt
# 2025-06-25 10:35:34,377 - INFO - Set jenis_perkara to 'Pidana Khusus Korupsi' for case_016.txt
# 2025-06-25 10:35:34,379 - INFO - Set tingkat_pemeriksaan to 'Kasasi' for case_016.txt
# 2025-06-25 10:35:34,380 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_016.txt
# 2025-06-25 10:35:34,381 - INFO - Extracted fallback pasal: pasal 18 for case_016.txt
# 2025-06-25 10:35:34,382 - INFO - Extracted hakim_ketua: h arizon mega jaya s h m h hakimad hoctindak pidana korupsi pada mahkamah agung dannoor edi yono s h m h hakim agungsebagai hakim hakim anggota putusan tersebutdiucapkan dalam sidang terbuka untuk umum pada hari for case_016.txt
# 2025-06-25 10:35:34,383 - INFO - Extracted ringkasan_fakta using pattern 1 for case_016.txt: menolak permohonan kasasi dari pemohon kasasi penuntut umumpada kejaksaan negeri surabayatersebut membebankan kepadaparaterdakwa untuk membayar biaya perkarapada tingkat kasasimasing masingsebesar rp2
# 2025-06-25 10:35:34,384 - INFO - Extracted jumlah_kata_putusan: 3982 for case_016.txt
# 2025-06-25 10:35:34,385 - INFO - Completed metadata extraction for case_016.txt
# 2025-06-25 10:35:34,385 - INFO - Processed text file: case_016.txt
# 2025-06-25 10:35:34,388 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pid sus' pattern: 
- INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_040.txt
# 2025-06-25 10:35:35,005 - INFO - Extracted fallback pasal: pasal 18 for case_040.txt
# 2025-06-25 10:35:35,007 - INFO - Extracted hakim_ketua: dr agustinus purnomo hadi s h m h hakimad hoctindak pidana korupsi pada mahkamah agungdansigid triyono s h m h hakimagung sebagai hakim hakim anggota putusan tersebutdiucapkan dalam sidang terbuka untuk umum pada hari for case_040.txt
# 2025-06-25 10:35:35,008 - INFO - Extracted ringkasan_fakta using pattern 1 for case_040.txt: sendiri perkara inidengan amar putusan sebagaimana yang akan disebutkan di bawah ini
# 2025-06-25 10:35:35,010 - INFO - Extracted jumlah_kata_putusan: 4778 for case_040.txt
# 2025-06-25 10:35:35,010 - INFO - Completed metadata extraction for case_040.txt
# 2025-06-25 10:35:35,011 - INFO - Processed text file: case_040.txt
# 2025-06-25 10:35:35,015 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pid sus' pattern: 5844 k pid sus 2024 for case_041.txt
# 2025-06-25 10:35:35,017 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2024 for case_041.txt
# 2025-06-25 10:35:35,018 - INFO - Extracted date: 22 September 2022 (Year: 2024, Month: September, Day: 22) for case_041.txt
# 2025-06-25 10:35:35,018 - INFO - Set jenis_perkara to 'Pidana Khusus Korupsi' for case_041.txt
# 2025-06-25 10:35:35,019 - INFO - Set tingkat_pemeriksaan to 'Kasasi' for case_041.txt
# 2025-06-25 10:35:35,020 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_041.txt
# 2025-06-25 10:35:35,022 - INFO - Extracted fallback pasal: pasal 2 ayat 1 for case_041.txt
# 2025-06-25 10:35:35,023 - WARNING - No hakim_ketua found in case_041.txt
# 2025-06-25 10:35:35,024 - INFO - Extracted ringkasan_fakta using pattern 1 for case_041.txt: sendiriperkara ini dengan amar putusan sebagaimana yang akan disebutkan dibawah ini
# 2025-06-25 10:35:35,025 - INFO - Extracted jumlah_kata_putusan: 7338 for case_041.txt
# 2025-06-25 10:35:35,026 - INFO - Completed metadata extraction for case_041.txt
# 2025-06-25 10:35:35,027 - INFO - Processed text file: case_041.txt
# 2025-06-25 10:35:35,031 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pid sus' pattern: 5848 k pid sus 2024 for case_042.txt
# 2025-06-25 10:35:35,034 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2024 for case_042.txt
# 2025-06-25 10:35:35,035 - INFO - Extracted date: 31 January 2024 (Year: 2024, Month: January, Day: 31) for case_042.txt
# 2025-06-25 10:35:35,036 - INFO - Set jenis_perkara to 'Pidana Khusus Korupsi' for case_042.txt
# 2025-06-25 10:35:35,037 - INFO - Set tingkat_pemeriksaan to 'Kasasi' for case_042.txt
# 2025-06-25 10:35:35,038 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_042.txt
# 2025-06-25 10:35:35,039 - INFO - Extracted fallback pasal: pasal 2 for case_042.txt
# 2025-06-25 10:35:35,041 - WARNING - No hakim_ketua found in case_042.txt
# 2025-06-25 10:35:35,041 - INFO - Extracted ringkasan_fakta using pattern 1 for case_042.txt: sendiri perkara inidengan amar putusan sebagaimana yang akan disebutkan di bawah ini
# 2025-06-25 10:35:35,043 - INFO - Extracted jumlah_kata_putusan: 8560 for case_042.txt
# 2025-06-25 10:35:35,044 - INFO - Completed metadata extraction for case_042.txt
# 2025-06-25 10:35:35,044 - INFO - Processed text file: case_042.txt
# 2025-06-25 10:35:35,049 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pid sus' pattern: 5920 k pid sus 2024 for case_043.txt
# 2025-06-25 10:35:35,051 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2024 for case_043.txt
# 2025-06-25 10:35:35,051 - INFO - Extracted date: 28 August 2023 (Year: 2024, Month: August, Day: 28) for case_043.txt
# 2025-06-25 10:35:35,052 - INFO - Set jenis_perkara to 'Pidana Khusus Korupsi' for case_043.txt
# 2025-06-25 10:35:35,053 - INFO - Set tingkat_pemeriksaan to 'Kasasi' for case_043.txt
# 2025-06-25 10:35:35,054 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_043.txt
# 2025-06-25 10:35:35,055 - INFO - Extracted pasal: pasal 2 ayat 1, Undang-Undang Nomor 31 tahun 1999 for case_043.txt
# 2025-06-25 10:35:35,056 - INFO - Extracted hakim_ketua: dr agustinus purnomo hadi s h m h hakim ad hoc tindak pidana korupsi pada mahkamah agung for case_043.txt
# 2025-06-25 10:35:35,058 - INFO - Extracted ringkasan_fakta using pattern 1 for case_043.txt: sendiri perkara ini dengan amar putusan sebagaimana yang akan disebutkan di bawah ini
# 2025-06-25 10:35:35,059 - INFO - Extracted jumlah_kata_putusan: 10456 for case_043.txt
# 2025-06-25 10:35:35,059 - INFO - Completed metadata extraction for case_043.txt
# 2025-06-25 10:35:35,060 - INFO - Processed text file: case_043.txt
# 2025-06-25 10:35:35,064 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pid sus' pattern: 5993 k pid sus 2024 for case_044.txt
# 2025-06-25 10:35:35,066 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2024 for case_044.txt
# 2025-06-25 10:35:35,067 - INFO - Extracted date: 28 November 2023 (Year: 2024, Month: November, Day: 28) for case_044.txt
# 2025-06-25 10:35:35,067 - INFO - Set jenis_perkara to 'Pidana Khusus Korupsi' for case_044.txt
# 2025-06-25 10:35:35,069 - INFO - Set tingkat_pemeriksaan to 'Kasasi' for case_044.txt
# 2025-06-25 10:35:35,070 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_044.txt
# 2025-06-25 10:35:35,070 - INFO - Extracted fallback pasal: pasal 2 ayat 1 for case_044.txt
# 2025-06-25 10:35:35,072 - INFO - Extracted hakim_ketua: dr agustinus purnomo hadi s h m h hakim ad hoc tindak pidana korupsi pada mahkamah agung for case_044.txt
# 2025-06-25 10:35:35,073 - INFO - Extracted ringkasan_fakta using pattern 1 for case_044.txt: menolak permohonan kasasi dari pemohon kasasi penuntut umum pada kejaksaan negeri bintan tersebut membebankan biaya perkara pada seluruh tingkat peradilan dan pada tingkat kasasi kepada negara
# 2025-06-25 10:35:35,074 - INFO - Extracted jumlah_kata_putusan: 4615 for case_044.txt
# 2025-06-25 10:35:35,075 - INFO - Completed metadata extraction for case_044.txt
# 2025-06-25 10:35:35,075 - INFO - Processed text file: case_044.txt
# 2025-06-25 10:35:35,077 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pid sus' pattern: 6092 k pid sus 2024 for case_045.txt
# 2025-06-25 10:35:35,078 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2024 for case_045.txt
# 2025-06-25 10:35:35,080 - INFO - Extracted date: 8 May 2024 (Year: 2024, Month: May, Day: 8) for case_045.txt
# 2025-06-25 10:35:35,082 - INFO - Set jenis_perkara to 'Pidana Khusus Korupsi' for case_045.txt
# 2025-06-25 10:35:35,083 - INFO - Set tingkat_pemeriksaan to 'Kasasi' for case_045.txt
# 2025-06-25 10:35:35,083 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_045.txt
# 2025-06-25 10:35:35,084 - INFO - Extracted fallback pasal: pasal 18 for case_045.txt
# 2025-06-25 10:35:35,086 - WARNING - No hakim_ketua found in case_045.txt
# 2025-06-25 10:35:35,087 - INFO - Extracted ringkasan_fakta using pattern 1 for case_045.txt: menolak permohonan kasasi dari pemohon kasasii penuntut umumpada kejaksaan negeripasaman barattersebut menolak permohonan kasasi daripemohon kasasi ii terdakwaaliamriltersebut halaman15dari16halaman p
# 2025-06-25 10:35:35,088 - INFO - Extracted jumlah_kata_putusan: 3453 for case_045.txt
# 2025-06-25 10:35:35,088 - INFO - Completed metadata extraction for case_045.txt
# 2025-06-25 10:35:35,089 - INFO - Processed text file: case_045.txt
# 2025-06-25 10:35:35,092 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pid sus' pattern: 6400 k pid sus 2024 for case_046.txt
# 2025-06-25 10:35:35,093 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2024 for case_046.txt
# 2025-06-25 10:35:35,095 - INFO - Extracted date: 16 August 2023 (Year: 2024, Month: August, Day: 16) for case_046.txt
# 2025-06-25 10:35:35,096 - INFO - Set jenis_perkara to 'Pidana Khusus Korupsi' for case_046.txt
# 2025-06-25 10:35:35,096 - INFO - Set tingkat_pemeriksaan to 'Kasasi' for case_046.txt
# 2025-06-25 10:35:35,097 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_046.txt
# 2025-06-25 10:35:35,099 - INFO - Extracted fallback pasal: pasal 2 ayat 1 for case_046.txt
# 2025-06-25 10:35:35,100 - INFO - Extracted hakim_ketua: h arizon mega jaya s h m h hakim ad hoc tindak pidana korupsi pada mahkamah agung for case_046.txt
# 2025-06-25 10:35:35,102 - INFO - Extracted ringkasan_fakta using pattern 1 for case_046.txt: telah dilaksanakan menurut dari 31 halaman putusan nomor 6400 k pid sus 2024 ketentuan undang undang bahwa berdasarkan fakta hukum yang terungkap di persidangan yaitu bahwa terdakwa selaku analis kred
# 2025-06-25 10:35:35,103 - INFO - Extracted jumlah_kata_putusan: 6518 for case_046.txt
# 2025-06-25 10:35:35,104 - INFO - Completed metadata extraction for case_046.txt
# 2025-06-25 10:35:35,105 - INFO - Processed text file: case_046.txt
# 2025-06-25 10:35:35,107 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pdt g' pattern: 766 pdt g 2025 for case_047.txt
# 2025-06-25 10:35:35,107 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2025 for case_047.txt
# 2025-06-25 10:35:35,108 - INFO - Extracted date: 26 May 2025 (Year: 2025, Month: May, Day: 26) for case_047.txt
# 2025-06-25 10:35:35,110 - INFO - Set jenis_perkara to 'Perdata' for case_047.txt
# 2025-06-25 10:35:35,110 - INFO - Set tingkat_pemeriksaan to 'Pertama' for case_047.txt
# 2025-06-25 10:35:35,112 - INFO - Set lembaga_peradilan to 'Pengadilan Agama' for case_047.txt
# 2025-06-25 10:35:35,113 - INFO - Extracted fallback pasal: pasal 89 ayat 1 for case_047.txt
# 2025-06-25 10:35:35,115 - WARNING - No hakim_ketua found in case_047.txt
# 2025-06-25 10:35:35,119 - INFO - Extracted ringkasan_fakta using pattern 1 for case_047.txt: perkara perdata agama pada tingkat pertama telahmenjatuhkan putusan perkara cerai gugat antara penggugat nik xxxxxx tempat dan tanggal lahir banyumas 05 januari1992 agama islam pendidikan sd pekerjaan
# 2025-06-25 10:35:35,120 - INFO - Extracted jumlah_kata_putusan: 949 for case_047.txt
# 2025-06-25 10:35:35,121 - INFO - Completed metadata extraction for case_047.txt
# 2025-06-25 10:35:35,123 - INFO - Processed text file: case_047.txt
# 2025-06-25 10:35:35,124 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pdt g' pattern: 883 pdt g 2025 for case_048.txt
# 2025-06-25 10:35:35,125 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2025 for case_048.txt
# 2025-06-25 10:35:35,127 - INFO - Extracted date: 08 May 2025 (Year: 2025, Month: May, Day: 8) for case_048.txt
# 2025-06-25 10:35:35,127 - INFO - Set jenis_perkara to 'Perdata' for case_048.txt
# 2025-06-25 10:35:35,129 - INFO - Set tingkat_pemeriksaan to 'Pertama' for case_048.txt
# 2025-06-25 10:35:35,131 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_048.txt
# 2025-06-25 10:35:35,133 - INFO - Extracted fallback pasal: pasal 49 for case_048.txt
# 2025-06-25 10:35:35,166 - WARNING - No hakim_ketua found in case_048.txt
# 2025-06-25 10:35:35,168 - INFO - Extracted ringkasan_fakta using pattern 1 for case_048.txt: perkara perdata agama pada tingkat pertama telahmenjatuhkan putusan dalam perkara cerai gugat antara penggugat umur 44 tahun agama islam pendidikan sd pekerjaanibu rumah tangga bertempat tinggal di ka
# 2025-06-25 10:35:35,169 - INFO - Extracted jumlah_kata_putusan: 3683 for case_048.txt
# 2025-06-25 10:35:35,169 - INFO - Completed metadata extraction for case_048.txt
# 2025-06-25 10:35:35,170 - INFO - Processed text file: case_048.txt
# 2025-06-25 10:35:35,171 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pdt p' pattern: 88 pdt p 2025 for case_049.txt
# 2025-06-25 10:35:35,171 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2025 for case_049.txt
# 2025-06-25 10:35:35,172 - INFO - Extracted date: 22 November 2024 (Year: 2025, Month: November, Day: 22) for case_049.txt
# 2025-06-25 10:35:35,173 - INFO - Set jenis_perkara to 'Perdata' for case_049.txt
# 2025-06-25 10:35:35,173 - INFO - Set tingkat_pemeriksaan to 'Pertama' for case_049.txt
# 2025-06-25 10:35:35,174 - INFO - Set lembaga_peradilan to 'Pengadilan Agama' for case_049.txt
# 2025-06-25 10:35:35,175 - INFO - Extracted fallback pasal: pasal 49 for case_049.txt
# 2025-06-25 10:35:35,175 - WARNING - No hakim_ketua found in case_049.txt
# 2025-06-25 10:35:35,176 - INFO - Extracted ringkasan_fakta using pattern 1 for case_049.txt: perkara tertentu pada tingkat pertama dalam sidang hakim telah menjatuhkan penetapan sebagai berikut dalam perkara dispensasi kawin yang diajukan oleh xxx tempat tanggal lahir sebalang 07 agustus 1979
# 2025-06-25 10:35:35,177 - INFO - Extracted jumlah_kata_putusan: 1435 for case_049.txt
# 2025-06-25 10:35:35,178 - INFO - Completed metadata extraction for case_049.txt
# 2025-06-25 10:35:35,179 - INFO - Processed text file: case_049.txt
# 2025-06-25 10:35:35,180 - INFO - Extracted nomor_perkara from 'penetapan/putusan nomor pdt g' pattern: 917 pdt g 2025 for case_050.txt
# 2025-06-25 10:35:35,181 - INFO - Extracted case year from nomor_perkara and set as tahun_putusan: 2025 for case_050.txt
# 2025-06-25 10:35:35,182 - INFO - Extracted date: 05 May 2025 (Year: 2025, Month: May, Day: 5) for case_050.txt
# 2025-06-25 10:35:35,183 - INFO - Set jenis_perkara to 'Perdata' for case_050.txt
# 2025-06-25 10:35:35,184 - INFO - Set tingkat_pemeriksaan to 'Pertama' for case_050.txt
# 2025-06-25 10:35:35,185 - INFO - Set lembaga_peradilan to 'Mahkamah Agung' for case_050.txt
# 2025-06-25 10:35:35,186 - INFO - Extracted fallback pasal: pasal 19 for case_050.txt
# 2025-06-25 10:35:35,212 - WARNING - No hakim_ketua found in case_050.txt
# 2025-06-25 10:35:35,214 - INFO - Extracted ringkasan_fakta using pattern 1 for case_050.txt: perkara perdata agama pada tingkat pertama telahmenjatuhkan putusan dalam perkara cerai gugat antara penggugat nik umur 45 tahun agama islam pendidikan d3 pekerjaan wiraswasta bertempat tinggal di kec
# 2025-06-25 10:35:35,216 - INFO - Extracted jumlah_kata_putusan: 3623 for case_050.txt
# 2025-06-25 10:35:35,216 - INFO - Completed metadata extraction for case_050.txt
# 2025-06-25 10:35:35,217 - INFO - Processed text file: case_050.txt
# 2025-06-25 10:35:35,263 - INFO - Saved 50 metadata entries to d:\AL FITRA\STUDI UMM\SEMESTER 6\TEORI\PENALARAN KOMPUTER\SOURCE CODE\PENALARAN KOMPUTER\CBR_Penalararan_Komputer\CBR\data\processed\cases.csv
# 2025-06-25 10:35:35,264 - INFO - Processed 50 files and saved to d:\AL FITRA\STUDI UMM\SEMESTER 6\TEORI\PENALARAN KOMPUTER\SOURCE CODE\PENALARAN KOMPUTER\CBR_Penalararan_Komputer\CBR\data\processed\cases.csv
